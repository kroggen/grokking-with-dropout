# %%
import torch
import matplotlib.pyplot as plt
results = torch.load("experiment_results.pt")

experiment_keys = [
    "add_mod|num_epochs-10000|train_fraction-0.5|optimizer-SGD|logg_frequency-100|lr-10.0|batch_size-6384|float_precision-64",
    "add_mod|num_epochs-10000|train_fraction-0.55|optimizer-SGD|logg_frequency-100|lr-10.0|batch_size-7022|float_precision-64",
    "add_mod|num_epochs-10000|train_fraction-0.6|optimizer-SGD|logg_frequency-100|lr-10.0|batch_size-7661|float_precision-64",
    "add_mod|num_epochs-10000|train_fraction-0.65|optimizer-SGD|logg_frequency-100|lr-10.0|batch_size-8299|float_precision-64",
    "add_mod|num_epochs-10000|train_fraction-0.7|optimizer-SGD|logg_frequency-100|lr-10.0|batch_size-8938|float_precision-64",
    "add_mod|num_epochs-10000|train_fraction-0.8|optimizer-SGD|logg_frequency-100|lr-10.0|batch_size-10215|float_precision-64",   
]

experiment_keys_32 = [
    "add_mod|num_epochs-10000|train_fraction-0.5|optimizer-SGD|logg_frequency-200|lr-10.0|batch_size-6384",
    "add_mod|num_epochs-10000|train_fraction-0.55|optimizer-SGD|logg_frequency-200|lr-10.0|batch_size-7022",
    "add_mod|num_epochs-10000|train_fraction-0.6|optimizer-SGD|logg_frequency-200|lr-10.0|batch_size-7661",
    "add_mod|num_epochs-10000|train_fraction-0.65|optimizer-SGD|logg_frequency-200|lr-10.0|batch_size-8299",
    "add_mod|num_epochs-10000|train_fraction-0.7|optimizer-SGD|logg_frequency-200|lr-10.0|batch_size-8938",
    "add_mod|num_epochs-10000|train_fraction-0.8|optimizer-SGD|logg_frequency-100|lr-10.0|batch_size-10215"
]


experiment_keys_32_stable = [
    "add_mod|num_epochs-10000|train_fraction-0.5|optimizer-SGD|loss_function-stable_softmax|logg_frequency-200|lr-10.0|batch_size-6384",
    "add_mod|num_epochs-10000|train_fraction-0.55|optimizer-SGD|loss_function-stable_softmax|logg_frequency-200|lr-10.0|batch_size-7022",
    "add_mod|num_epochs-10000|train_fraction-0.6|optimizer-SGD|loss_function-stable_softmax|logg_frequency-200|lr-10.0|batch_size-7661",
    "add_mod|num_epochs-10000|train_fraction-0.65|optimizer-SGD|loss_function-stable_softmax|logg_frequency-200|lr-10.0|batch_size-8299",
    "add_mod|num_epochs-10000|train_fraction-0.7|optimizer-SGD|loss_function-stable_softmax|logg_frequency-200|lr-10.0|batch_size-8938",
    "add_mod|num_epochs-10000|train_fraction-0.8|optimizer-SGD|loss_function-stable_softmax|logg_frequency-200|lr-10.0|batch_size-10215"
]


experiment_keys_64_stable = [
    "add_mod|num_epochs-10000|train_fraction-0.5|optimizer-SGD|loss_function-stable_softmax|logg_frequency-200|lr-10.0|batch_size-6384|float_precision-64",
    "add_mod|num_epochs-10000|train_fraction-0.55|optimizer-SGD|loss_function-stable_softmax|logg_frequency-200|lr-10.0|batch_size-7022|float_precision-64",
    "add_mod|num_epochs-10000|train_fraction-0.6|optimizer-SGD|loss_function-stable_softmax|logg_frequency-200|lr-10.0|batch_size-7661|float_precision-64",
    "add_mod|num_epochs-10000|train_fraction-0.65|optimizer-SGD|loss_function-stable_softmax|logg_frequency-200|lr-10.0|batch_size-8299|float_precision-64",
    "add_mod|num_epochs-10000|train_fraction-0.7|optimizer-SGD|loss_function-stable_softmax|logg_frequency-200|lr-10.0|batch_size-8938|float_precision-64",
    "add_mod|num_epochs-10000|train_fraction-0.8|optimizer-SGD|loss_function-stable_softmax|logg_frequency-200|lr-10.0|batch_size-10215|float_precision-64"
]


input_representation_eperiment_keys = [
            "add_mod|num_epochs-1000|train_fraction-0.4|logg_frequency-10|lr-0.02|batch_size-5107|float_precision-64",
            "scalar_alg|num_epochs-1000|train_fraction-0.4|logg_frequency-10|lr-0.02|batch_size-5107|dataset-scalar_alg|float_precision-64",
            "binary_alg|num_epochs-1000|train_fraction-0.4|logg_frequency-10|lr-0.02|batch_size-5107|dataset-binary_alg|float_precision-64"
]


float32_vs_float64_experiment_keys = {
    0.4:[
        "add_mod|num_epochs-10000|train_fraction-0.4|optimizer-SGD|logg_frequency-200|lr-10.0|batch_size-5107|use_lr_scheduler-True",
        "add_mod|num_epochs-10000|train_fraction-0.4|optimizer-SGD|logg_frequency-200|lr-10.0|batch_size-5107|float_precision-64|use_lr_scheduler-True",
        "add_mod|num_epochs-10000|train_fraction-0.4|optimizer-SGD|loss_function-stable_softmax|logg_frequency-200|lr-10.0|batch_size-5107|float_precision-64|use_lr_scheduler-True"
    ],
    0.6:[
        "add_mod|num_epochs-10000|train_fraction-0.6|optimizer-SGD|logg_frequency-200|lr-10.0|batch_size-7661|use_lr_scheduler-True",
        "add_mod|num_epochs-10000|train_fraction-0.6|optimizer-SGD|logg_frequency-200|lr-10.0|batch_size-7661|float_precision-64|use_lr_scheduler-True",
        "add_mod|num_epochs-10000|train_fraction-0.6|optimizer-SGD|loss_function-stable_softmax|logg_frequency-200|lr-10.0|batch_size-7661|float_precision-64|use_lr_scheduler-True"
    ],
    0.7: [
        "add_mod|num_epochs-10000|train_fraction-0.7|optimizer-SGD|logg_frequency-200|lr-10.0|batch_size-8938|use_lr_scheduler-True",
        "add_mod|num_epochs-10000|train_fraction-0.7|optimizer-SGD|logg_frequency-200|lr-10.0|batch_size-8938|float_precision-64|use_lr_scheduler-True",
        "add_mod|num_epochs-10000|train_fraction-0.7|optimizer-SGD|loss_function-stable_softmax|logg_frequency-200|lr-10.0|batch_size-8938|float_precision-64|use_lr_scheduler-True"
]
}

gradient_norm_experiment_keys = [
    "add_mod|num_epochs-20000|optimizer-SGD|logg_frequency-1000|lr-20.0|batch_size-3830",
    "add_mod|num_epochs-20000|train_fraction-0.4|optimizer-SGD|logg_frequency-1000|lr-20.0|batch_size-5107"
]

softer_max_experiment_keys = [
    "add_mod|num_epochs-20000|train_fraction-0.4|optimizer-SGD|loss_function-softermax|logg_frequency-500|lr-500.0|batch_size-5107|float_precision-64|use_lr_scheduler-True",
    "product_mod|num_epochs-20000|train_fraction-0.4|optimizer-SGD|loss_function-softermax|logg_frequency-500|lr-500.0|batch_size-5107|dataset-product_mod|float_precision-64|use_lr_scheduler-True",
    "sparse_parity|num_epochs-20000|train_fraction-0.5|optimizer-SGD|loss_function-softermax|logg_frequency-500|lr-1.0|batch_size-1000|dataset-sparse_parity|num_noise_features-40|num_parity_features-3|num_samples-2000|float_precision-64|use_lr_scheduler-True",
]

stablemax_experiment_keys = [
    "add_mod|num_epochs-100000|train_fraction-0.4|loss_function-stablemax|logg_frequency-5000|lr-0.01|batch_size-5107|float_precision-64",
    "product_mod|num_epochs-100000|train_fraction-0.4|loss_function-stablemax|logg_frequency-5000|lr-0.01|batch_size-5107|dataset-product_mod|float_precision-64",
    "sparse_parity|num_epochs-100000|train_fraction-0.5|loss_function-stablemax|logg_frequency-5000|lr-0.01|batch_size-1000|dataset-sparse_parity|num_noise_features-40|num_parity_features-3|num_samples-2000|float_precision-64"
]

transformer_orthogonal_gradients_experiments = [
    
    "add_mod|num_epochs-10000|train_fraction-0.4|logg_frequency-500|lr-0.001|batch_size-5017",
    "add_mod|num_epochs-10000|train_fraction-0.4|loss_function-stablemax|logg_frequency-500|lr-0.001|batch_size-5017|orthogonal_gradients-True",
    "add_mod|num_epochs-10000|train_fraction-0.4|logg_frequency-500|lr-0.001|batch_size-5017|weight_decay-1.5"
]
mlp_orthogonal_gradients_experiments = [
"add_mod|num_epochs-500|train_fraction-0.4|logg_frequency-20|lr-0.005|batch_size-5107|float_precision-64",
"add_mod|num_epochs-500|train_fraction-0.4|optimizer-SGD|loss_function-softermax|logg_frequency-20|lr-10.0|batch_size-5107|float_precision-64|orthogonal_gradients-True",
"add_mod|num_epochs-500|train_fraction-0.4|logg_frequency-20|lr-0.005|batch_size-5107|float_precision-64|orthogonal_gradients-True"
]

model_trajectory_experiments = [
    "add_mod|num_epochs-10000|train_fraction-0.4|optimizer-SGD|logg_frequency-1000|lr-1.0|batch_size-5107|float_precision-64"
]


teaser_plot_experiments = [
    "add_mod|num_epochs-20000|train_fraction-0.4|optimizer-SGD|loss_function-softermax|logg_frequency-500|lr-500.0|batch_size-5107|float_precision-64|use_lr_scheduler-True",
    "add_mod|num_epochs-10000|train_fraction-0.4|logg_frequency-1000|lr-0.001|batch_size-5017|weight_decay-1.0",
    "add_mod|num_epochs-10000|train_fraction-0.4|optimizer-SGD|logg_frequency-200|lr-10.0|batch_size-5107|use_lr_scheduler-True"

]
float32_vs_float64_adamw_experiment_keys = {
    0.6:[
        "add_mod|num_epochs-20000|train_fraction-0.6|logg_frequency-1000|lr-0.001|batch_size-7661|float_precision-16",
        "add_mod|num_epochs-20000|train_fraction-0.6|logg_frequency-1000|lr-0.001|batch_size-7661",
        "add_mod|num_epochs-20000|train_fraction-0.6|logg_frequency-1000|lr-0.001|batch_size-7661|float_precision-64",
        "add_mod|num_epochs-20000|train_fraction-0.6|loss_function-stable_ce|logg_frequency-1000|lr-0.001|batch_size-7661|float_precision-64",
    ],
    0.4:[
        "add_mod|num_epochs-20000|train_fraction-0.4|logg_frequency-1000|lr-0.001|batch_size-5107|float_precision-16",
        "add_mod|num_epochs-20000|train_fraction-0.4|logg_frequency-1000|lr-0.001|batch_size-5107",
        "add_mod|num_epochs-20000|train_fraction-0.4|logg_frequency-1000|lr-0.001|batch_size-5107|float_precision-64",
        "add_mod|num_epochs-20000|train_fraction-0.4|loss_function-stable_ce|logg_frequency-1000|lr-0.001|batch_size-5107|float_precision-64"
    ],
    0.7: [
        "add_mod|num_epochs-20000|train_fraction-0.7|logg_frequency-1000|lr-0.001|batch_size-8938|float_precision-16",
        "add_mod|num_epochs-20000|train_fraction-0.7|logg_frequency-1000|lr-0.001|batch_size-8938",
        "add_mod|num_epochs-20000|train_fraction-0.7|logg_frequency-1000|lr-0.001|batch_size-8938|float_precision-64",
        "add_mod|num_epochs-20000|train_fraction-0.7|loss_function-stable_ce|logg_frequency-1000|lr-0.001|batch_size-8938|float_precision-64"
]
}

reducing_weight_decay_experiments = [
    "add_mod|num_epochs-10000|logg_frequency-1000|lr-0.01|batch_size-3830|weight_decay-1.0",
]

intervention_sc_stops_grokking = [
    "add_mod|num_epochs-20000|train_fraction-0.6|loss_function-stable_ce|logg_frequency-1000|lr-0.001|batch_size-7661|float_precision-64",
    "add_mod|num_epochs-20000|train_fraction-0.6|loss_function-stable_ce|logg_frequency-1000|lr-0.001|batch_size-7661|float_precision-64|asc-True"
]
# Out:
# /tmp/ipykernel_1054282/86028118.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   results = torch.load("experiment_results.pt")
# ...

# %%
import pandas as pd
def format_func(value, tick_number):
    if value == 0:
        return "0"
    elif value >= 1000:
        return f"{int(value/1000)}k"
    else:
        return str(int(value))

def get_metric_values(df, input_type, metric_name):
    if input_type not in df["input_type"].unique():
        raise ValueError(f"'{input_type}' is not a valid input_type. "
                         f"Available: {df['input_type'].unique().tolist()}")
    if metric_name not in df["metric_name"].unique():
        raise ValueError(f"'{metric_name}' is not a valid metric_name. "
                         f"Available: {df['metric_name'].unique().tolist()}")
    
    metric_values = df[(df["input_type"] == input_type) &
                       (df["metric_name"] == metric_name)]["value"]
    return metric_values.values

def read_metrics(experiment_key: str) -> [pd.DataFrame, int]:
    experiment_metrics = pd.read_csv(f"loggs/{experiment_key}/metrics.csv")
    num_loged_epochs = experiment_metrics["epoch"].max() + 1
    return experiment_metrics, num_loged_epochs

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import pandas as pd

experiment_key = "add_mod|num_epochs-80000|train_fraction-0.4|loss_function-stablemax|log_frequency-5000|lr-0.01|batch_size-5107|device-cuda:0"

experiment_metrics, num_logged_epochs = read_metrics(experiment_key)

log_frequency = 5000
epochs = range(0, log_frequency * (num_logged_epochs), log_frequency)

train_accuracy = get_metric_values(experiment_metrics, "train", "accuracy")
test_accuracy = get_metric_values(experiment_metrics, "test", "accuracy")

fig, ax = plt.subplots(figsize=(6, 5))

ax.plot(epochs, train_accuracy, linewidth=5, label='Training accuracy')
ax.plot(epochs, test_accuracy, linewidth=5, label='Test accuracy')

ax.set_xlabel('Epoch', fontsize=18)
ax.set_ylabel('Accuracy (%)', fontsize=18)

ax.grid(alpha=0.5)
ax.legend(fontsize=14, loc="lower right")

ax.xaxis.set_major_formatter(FuncFormatter(format_func))

ax.set_xticks(epochs[::2])
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

experiment_key = "add_mod|num_epochs-300|train_fraction-0.4|log_frequency-10|lr-0.008|batch_size-5107|orthogonal_gradients-True|device-cuda:0"
experiment_metrics, num_logged_epochs = read_metrics(experiment_key)

train_accuracy = get_metric_values(experiment_metrics, "train", "accuracy")
test_accuracy = get_metric_values(experiment_metrics, "test", "accuracy")

fig, ax = plt.subplots(figsize=(6, 5))

ax.plot(epochs, train_accuracy, linewidth=5, label='Training accuracy')
ax.plot(epochs, test_accuracy, linewidth=5, label='Test accuracy')

ax.set_xlabel('Epoch', fontsize=18)
ax.set_ylabel('Accuracy (%)', fontsize=18)

ax.grid(alpha=0.5)
ax.legend(fontsize=14)

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

experiment_key = "add_mod|num_epochs-80000|train_fraction-0.4|log_frequency-5000|lr-0.001|batch_size-5107|device-cuda:0"
experiment_metrics, num_logged_epochs = read_metrics(experiment_key)


train_accuracy = get_metric_values(experiment_metrics, "train", "accuracy")
test_accuracy = get_metric_values(experiment_metrics, "test", "accuracy")

log_frequency = 5000
epochs = range(0, log_frequency * (experiment_metrics["epoch"].max()+1), log_frequency)

fig, ax = plt.subplots(figsize=(6, 5))

ax.plot(epochs, train_accuracy, linewidth=5, label='Training accuracy')
ax.plot(epochs, test_accuracy, linewidth=5, label='Test accuracy')

ax.set_xlabel('Epoch', fontsize=18)
ax.set_ylabel('Accuracy (%)', fontsize=18)

ax.grid(alpha=0.5)
ax.legend(fontsize=14)

ax.xaxis.set_major_formatter(FuncFormatter(format_func))
ax.set_xticks(epochs[::2])  


plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import pandas as pd

experiment_key = "add_mod|num_epochs-5000|train_fraction-0.4|log_frequency-200|lr-0.008|batch_size-5017|orthogonal_gradients-True|use_transformer-True|device-cuda:0"

experiment_metrics, num_logged_epochs = read_metrics(experiment_key)

log_frequency = 200
epochs = range(0, log_frequency * (num_logged_epochs), log_frequency)

train_accuracy = get_metric_values(experiment_metrics, "train", "accuracy")
test_accuracy = get_metric_values(experiment_metrics, "test", "accuracy")

fig, ax = plt.subplots(figsize=(6, 5))

ax.plot(epochs, train_accuracy, linewidth=5, label='Training accuracy')
ax.plot(epochs, test_accuracy, linewidth=5, label='Test accuracy')

ax.set_xlabel('Epoch', fontsize=18)
ax.set_ylabel('Accuracy (%)', fontsize=18)

ax.grid(alpha=0.5)
ax.legend(fontsize=14, loc="lower right")


ax.set_xticks(epochs[::4])
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
colors  = ['#1f77b4', '#ff7f0e', '#2ca02c']#plt.get_cmap("tab10").colors
log_frequency = 20
train_fraction = 0.7
experiment_results_baseline = results[mlp_orthogonal_gradients_experiments[0]]
experiment_results_orth_sgd = results[mlp_orthogonal_gradients_experiments[1]]
experiment_results_orth_adamw = results[mlp_orthogonal_gradients_experiments[2]]

linewidth = 3

epochs = range(0, log_frequency * len(experiment_results_baseline["train"]["accuracy"]), log_frequency)
plt.plot(epochs, experiment_results_orth_adamw["test"]["accuracy"],linewidth=linewidth, label='Test accuracy stable sum', color=colors[2])

plt.plot(epochs, experiment_results_baseline["test"]["accuracy"], linewidth=linewidth, color=colors[1], label='Test accuracy float32')

plt.plot(epochs, experiment_results_baseline["train"]["accuracy"], linewidth=linewidth, alpha=0.9, color=colors[1],linestyle='--')

plt.plot(epochs, experiment_results_orth_sgd["test"]["accuracy"],linewidth=linewidth,  color=colors[0], label='Test accuracy float64')
plt.plot(epochs, experiment_results_orth_sgd["train"]["accuracy"],linewidth=linewidth, alpha=0.9, color=colors[0], linestyle='--')
plt.plot(epochs, experiment_results_orth_adamw["train"]["accuracy"],linewidth=linewidth, linestyle='--', color=colors[2])



plt.xlabel('Epoch', fontsize=18)
plt.ylabel('Accuracy (%)', fontsize=18)


plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.ylim(-1, 105)


legend_elements = [
    Line2D([0], [0], color=colors[1], lw=2, label='Test acc. - AdamW'),
    Line2D([0], [0], color=colors[0], lw=2, label='Test acc. - $\perp$SGD'),
    Line2D([0], [0], color=colors[2], lw=2, label='Test acc. - $\perp$AdamW'),
    Line2D([0], [0], color='gray', lw=2, linestyle='--', label='Train accuracies'),
]


plt.legend(handles=legend_elements, loc='lower right', 
             fontsize=14, framealpha=0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)


plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
colors  = ['#1f77b4', '#ff7f0e', '#2ca02c']
log_frequency = 500
train_fraction = 0.7
experiment_results = results[transformer_orthogonal_gradients_experiments[0]]
experiment_results_orthogonal = results[transformer_orthogonal_gradients_experiments[1]]
experiment_results_weight_decay = results[transformer_orthogonal_gradients_experiments[2]]
experiment_results["train_accuracy_list"] = []
experiment_results_orthogonal["train_accuracy_list"] = []
experiment_results_weight_decay["train_accuracy_list"] = []

experiment_results["test_accuracy_list"] = []
experiment_results_orthogonal["test_accuracy_list"] = []
experiment_results_weight_decay["test_accuracy_list"] = []
epochs = []
for epoch in experiment_results.keys():
    if isinstance(epoch, int):
        epochs.append(epoch)
        experiment_results["train_accuracy_list"] .append(experiment_results[epoch]["train_accuracy"])
        experiment_results["test_accuracy_list"] .append(experiment_results[epoch]["test_accuracy"])

        experiment_results_orthogonal["train_accuracy_list"].append(experiment_results_orthogonal[epoch]["train_accuracy"])
        experiment_results_orthogonal["test_accuracy_list"].append(experiment_results_orthogonal[epoch]["test_accuracy"])
    
        experiment_results_weight_decay["train_accuracy_list"].append(experiment_results_weight_decay[epoch]["train_accuracy"])
        experiment_results_weight_decay["test_accuracy_list"].append(experiment_results_weight_decay[epoch]["test_accuracy"])


plt.plot(epochs, experiment_results_weight_decay["test_accuracy_list"],linewidth=3, label='Test accuracy stable sum', color=colors[2])

plt.plot(epochs, experiment_results["test_accuracy_list"], linewidth=3, color=colors[1], label='Test accuracy float32')

plt.plot(epochs, experiment_results["train_accuracy_list"], linewidth=3, alpha=0.9, color=colors[1],linestyle='--')

plt.plot(epochs, experiment_results_orthogonal["test_accuracy_list"],linewidth=3,  color=colors[0], label='Test accuracy float64')

plt.plot(epochs, experiment_results_weight_decay["train_accuracy_list"],linewidth=3, linestyle='--', color=colors[2])

plt.plot(epochs, experiment_results_orthogonal["train_accuracy_list"],linewidth=3, alpha=0.9, color=colors[0], linestyle='--')


plt.xlabel('Epoch', fontsize=18)
plt.ylabel('Accuracy', fontsize=18)


plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.ylim(-1, 105)


legend_elements = [
    Line2D([0], [0], color=colors[1], lw=2, label='Test acc. - AdamW'),
    Line2D([0], [0], color=colors[0], lw=2, label='Test acc. - $\perp$AdamW'),
    Line2D([0], [0], color=colors[2], lw=2, label='Test acc. - AdamW \n + weight decay'),
    Line2D([0], [0], color='gray', lw=2, linestyle='--', label='Train accuracies'),

]

plt.legend(handles=legend_elements, loc='lower right', 
             fontsize=14, framealpha=0)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlim(-100, 5000)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

from matplotlib.ticker import FuncFormatter

def format_func(value, tick_number):
    if value == 0:
        return "0"
    elif value >= 1000:
        return f"{int(value/1000)}k"
    else:
        return str(int(value))
    
colors  = ['#1f77b4', '#ff7f0e', '#2ca02c']
log_frequency = 5000
train_fraction = 0.7
experiment_results = results[stablemax_experiment_keys[0]]
experiment_results_64 = results[stablemax_experiment_keys[1]]
experiment_results_64_stable_sum = results[stablemax_experiment_keys[2]]
linewidth = 4
fig, ax = plt.subplots(figsize=(6, 5))

epochs = range(0, log_frequency * len(experiment_results["train"]["accuracy"]), log_frequency)
ax.plot(epochs, experiment_results_64_stable_sum["test"]["accuracy"],linewidth=linewidth, label='Test accuracy stable sum', color=colors[2])

ax.plot(epochs, experiment_results["test"]["accuracy"], linewidth=linewidth, color=colors[1], label='Test accuracy float32')

ax.plot(epochs, experiment_results["train"]["accuracy"], linewidth=linewidth, alpha=0.9, color=colors[1],linestyle='--')
#plt.plot(epochs,torch.tensor(zero_terms32)*100, color=colors[0], linestyle='--',label="Zero loss terms float32 (%)")

ax.plot(epochs, experiment_results_64["test"]["accuracy"],linewidth=linewidth,  color=colors[0], label='Test accuracy float64')
ax.plot(epochs, experiment_results_64["train"]["accuracy"],linewidth=linewidth, alpha=0.9, color=colors[0], linestyle='--')
#plt.plot(epochs, torch.tensor(experiment_results_64_stable_sum["train"]["zero_terms"])*100)
ax.plot(epochs, experiment_results_64_stable_sum["train"]["accuracy"],linewidth=linewidth, linestyle='--', color=colors[2])



plt.xlabel('Epoch', fontsize=18)
plt.ylabel('Accuracy (%)', fontsize=18)


ax.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.ylim(-1, 105)

legend_elements = [
    Line2D([0], [0], color=colors[1], lw=2, label='Test acc. -\n addition\n mod 113'),
    Line2D([0], [0], color=colors[0], lw=2, label='Test acc. -\n product\n mod 113'),
    Line2D([0], [0], color=colors[2], lw=2, label='Test acc. -\n sparse parity\n (n=40, k=3)'),
    Line2D([0], [0], color='gray', lw=2, linestyle='--', label='Train acc.'),
]
ax.xaxis.set_major_formatter(FuncFormatter(format_func))
ax.set_xticks(epochs[::4])

ax.legend(handles=legend_elements, loc='lower right', 
             fontsize=14, framealpha=0)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)


plt.show()

# %%
neurons_by_layer = [226*200, 200*200, 200*113]
layers = [f"linear_{i}" for i in range(3)]

add_mod_norm = sum(experiment_results["general"]['weights_l2'][layer]*neurons_by_layer[i] for i, layer in enumerate(layers)).sqrt()
prod_mod_norm = sum(experiment_results_64["general"]['weights_l2'][layer]*neurons_by_layer[i] for i, layer in enumerate(layers)).sqrt()
sparse_parity_norm = sum(experiment_results_64_stable_sum["general"]['weights_l2'][layer]*neurons_by_layer[i] for i, layer in enumerate(layers)).sqrt()

# %%
fig, ax = plt.subplots(figsize=(6, 5))

plt.plot(epochs, add_mod_norm, linewidth=5, label="addition mod 113 L2 norm")
plt.plot(epochs, prod_mod_norm, linewidth=5, label="product mod 113 L2 norm")
plt.plot(epochs , sparse_parity_norm, linewidth=5, label="Sparse parity L2 norm")
plt.grid(True, linestyle='--', alpha=0.7)

plt.ylabel("Weight norm (L2)", fontsize=18)
plt.xlabel("Epoch", fontsize=18)
ax.xaxis.set_major_formatter(FuncFormatter(format_func))
ax.set_xticks(epochs[::4])

ax.yaxis.set_major_formatter(FuncFormatter(format_func))

plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=14, framealpha=0)
plt.savefig("weight_norms.pdf", bbox_inches='tight', pad_inches=0)

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.ticker import FuncFormatter
import torch

def format_func(value, tick_number):
    if value == 0:
        return "0"
    elif value >= 1000:
        return f"{int(value/1000)}k"
    else:
        return str(int(value))

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#9467bd']

experiment_keys = ["add_mod|num_epochs-20000|train_fraction-0.7|log_frequency-500|lr-0.0005|batch_size-8938|float_precision-16|device-cuda:7",
                   "add_mod|num_epochs-20000|train_fraction-0.7|log_frequency-500|lr-0.0005|batch_size-8938|device-cuda:7",
                   "add_mod|num_epochs-20000|train_fraction-0.7|log_frequency-500|lr-0.0005|batch_size-8938|float_precision-64|device-cuda:7"]


log_frequency = 200




train_fraction = 0.6
experiment_results_16, num_logged_epochs = read_metrics(experiment_keys[0])
experiment_results_32, _  = read_metrics(experiment_keys[1])
experiment_results_64, _ = read_metrics(experiment_keys[2])
linewidth = 3

fig, ax = plt.subplots(figsize=(6, 5))
epochs = range(0, log_frequency * (num_logged_epochs), log_frequency)


train_accuracy_16 = get_metric_values(experiment_results_16, "train", "accuracy")*100
test_accuracy_16 = get_metric_values(experiment_results_16, "test", "accuracy")*100
softmax_collapse_16 = get_metric_values(experiment_results_16, "train", "softmax_collapse")

train_accuracy_32 = get_metric_values(experiment_results_32, "train", "accuracy")*100
test_accuracy_32 = get_metric_values(experiment_results_32, "test", "accuracy")*100
softmax_collapse_32 = get_metric_values(experiment_results_32, "train", "softmax_collapse")

train_accuracy_64 = get_metric_values(experiment_results_64, "train", "accuracy")*100
test_accuracy_64 = get_metric_values(experiment_results_64, "test", "accuracy")*100
softmax_collapse_64 = get_metric_values(experiment_results_64, "train", "softmax_collapse")


#ax.plot(epochs, experiment_results_64_stable_sum["test"]["accuracy"], linewidth=linewidth, label='Test accuracy stable sum', color=colors[2])
ax.plot(epochs, test_accuracy_32, linewidth=linewidth, color=colors[1], label='Test accuracy float32')
ax.plot(epochs, train_accuracy_32, linewidth=linewidth, alpha=0.9, color=colors[1], linestyle='--')
ax.plot(epochs, test_accuracy_64, linewidth=linewidth, color=colors[2], label='Test accuracy float64')
ax.plot(epochs, train_accuracy_64, linewidth=linewidth, alpha=0.9, color=colors[2], linestyle='--')
#ax.plot(epochs, experiment_results_64_stable_sum["train"]["accuracy"], linewidth=linewidth, linestyle='--', color=colors[2])
ax.plot(epochs, test_accuracy_16, linewidth=linewidth, color=colors[0], label='Test accuracy float16')

ax.set_xlabel('Epoch', fontsize=18)


ax.axvline(torch.where(torch.tensor(softmax_collapse_32>0.5))[0][0]*log_frequency, color=colors[1], linewidth=2.5, linestyle=':', label="50% zero terms in the loss")
ax.axvline(torch.where(torch.tensor(softmax_collapse_64>0.5))[0][0]*log_frequency, color=colors[2], linewidth=2.5, linestyle=':', label="50% zero terms in the loss")
ax.axvline(torch.where(torch.tensor(softmax_collapse_16>0.5))[0][0]*log_frequency, color=colors[0], linewidth=2.5, linestyle=':', label="50% zero terms in the loss")


ax.grid(True, linestyle='--', alpha=0.7)
ax.set_ylim(-1, 105)

# Add both the test accuracy labels and the manual gray line
legend_elements = [
    Line2D([0], [0], color=colors[3], lw=2, label='Test acc. - float16'),
    Line2D([0], [0], color=colors[1], lw=2, label='Test acc. - float32'),
    Line2D([0], [0], color=colors[0], lw=2, label='Test acc. - float64'),
    Line2D([0], [0], color=colors[2], lw=2, label='Test acc. - stable sum\n float64'),
    Line2D([0], [0], color='gray', lw=2, linestyle='--', label='Train accuracies'),
    Line2D([0], [0], color='gray', lw=2, linestyle=':', label='50% Softmax Collapse'),
]
ax.set_yticklabels([])
# Add the legend outside the plot on the right
#ax.legend(handles=legend_elements, loc='center left', bbox_to_anchor=(1, 0.5), fontsize=14)

ax.tick_params(axis='both', labelsize=16)
ax.xaxis.set_major_formatter(FuncFormatter(format_func))

plt.tight_layout()  # Adjust the layout to prevent clipping of labels

plt.savefig('float32vsfloat64_70_percent_no_legend.pdf', bbox_inches='tight')  # Uncomment to save the figure
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import torch


from matplotlib.ticker import FuncFormatter

def format_func(value, tick_number):
    if value == 0:
        return "0"
    elif value >= 1000:
        return f"{int(value/1000)}k"
    else:
        return str(int(value))

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#9467bd']

experiment_keys = ["add_mod|num_epochs-20000|train_fraction-0.6|log_frequency-200|lr-0.0005|batch_size-7661|float_precision-16|device-cuda:7",
                   "add_mod|num_epochs-20000|train_fraction-0.6|log_frequency-200|lr-0.0005|batch_size-7661|device-cuda:7",
                   "add_mod|num_epochs-20000|train_fraction-0.6|log_frequency-200|lr-0.0005|batch_size-7661|float_precision-64|device-cuda:7"]


log_frequency = 200




train_fraction = 0.6
experiment_results_16, num_logged_epochs = read_metrics(experiment_keys[0])
experiment_results_32, _  = read_metrics(experiment_keys[1])
experiment_results_64, _ = read_metrics(experiment_keys[2])
linewidth = 3

fig, ax = plt.subplots(figsize=(6, 5))
epochs = range(0, log_frequency * (num_logged_epochs), log_frequency)


train_accuracy_16 = get_metric_values(experiment_results_16, "train", "accuracy")*100
test_accuracy_16 = get_metric_values(experiment_results_16, "test", "accuracy")*100
softmax_collapse_16 = get_metric_values(experiment_results_16, "train", "softmax_collapse")

train_accuracy_32 = get_metric_values(experiment_results_32, "train", "accuracy")*100
test_accuracy_32 = get_metric_values(experiment_results_32, "test", "accuracy")*100
softmax_collapse_32 = get_metric_values(experiment_results_32, "train", "softmax_collapse")

train_accuracy_64 = get_metric_values(experiment_results_64, "train", "accuracy")*100
test_accuracy_64 = get_metric_values(experiment_results_64, "test", "accuracy")*100
softmax_collapse_64 = get_metric_values(experiment_results_64, "train", "softmax_collapse")


#ax.plot(epochs, experiment_results_64_stable_sum["test"]["accuracy"], linewidth=linewidth, label='Test accuracy stable sum', color=colors[2])
ax.plot(epochs, test_accuracy_32, linewidth=linewidth, color=colors[1], label='Test accuracy float32')
ax.plot(epochs, train_accuracy_32, linewidth=linewidth, alpha=0.9, color=colors[1], linestyle='--')
ax.plot(epochs, test_accuracy_64, linewidth=linewidth, color=colors[2], label='Test accuracy float64')
ax.plot(epochs, train_accuracy_64, linewidth=linewidth, alpha=0.9, color=colors[2], linestyle='--')
#ax.plot(epochs, experiment_results_64_stable_sum["train"]["accuracy"], linewidth=linewidth, linestyle='--', color=colors[2])
ax.plot(epochs, test_accuracy_16, linewidth=linewidth, color=colors[0], label='Test accuracy float16')

ax.set_xlabel('Epoch', fontsize=18)


ax.axvline(torch.where(torch.tensor(softmax_collapse_32>0.5))[0][0]*log_frequency, color=colors[1], linewidth=2.5, linestyle=':', label="50% zero terms in the loss")
ax.axvline(torch.where(torch.tensor(softmax_collapse_64>0.5))[0][0]*log_frequency, color=colors[2], linewidth=2.5, linestyle=':', label="50% zero terms in the loss")
ax.axvline(torch.where(torch.tensor(softmax_collapse_16>0.5))[0][0]*log_frequency, color=colors[0], linewidth=2.5, linestyle=':', label="50% zero terms in the loss")


ax.grid(True, linestyle='--', alpha=0.7)
ax.set_ylim(-1, 105)


legend_elements = [
    Line2D([0], [0], color=colors[3], lw=2, label='Test acc. - float16'),
    Line2D([0], [0], color=colors[1], lw=2, label='Test acc. - float32'),
    Line2D([0], [0], color=colors[0], lw=2, label='Test acc. - float64'),
    Line2D([0], [0], color=colors[2], lw=2, label='Test acc. - stable_sum_fp64'),
    Line2D([0], [0], color='gray', lw=2, linestyle='--', label='Train accuracies'),
    Line2D([0], [0], color='gray', lw=2, linestyle=':', label='50% Softmax Collapse'),
]



ax.tick_params(axis='both', which='major', labelsize=16)
ax.xaxis.set_major_formatter(FuncFormatter(format_func))

ax.set_yticklabels([])
plt.tight_layout()  

plt.savefig('float32vsfloat64_60_percent.pdf', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import torch
from matplotlib.ticker import FuncFormatter
import torch

def format_func(value, tick_number):
    if value == 0:
        return "0"
    elif value >= 1000:
        return f"{int(value/1000)}k"
    else:
        return str(int(value))

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#9467bd']

experiment_keys = ["add_mod|num_epochs-20000|train_fraction-0.4|log_frequency-200|lr-0.0005|batch_size-5107|float_precision-16|device-cuda:7",
                   "add_mod|num_epochs-20000|train_fraction-0.4|log_frequency-200|lr-0.0005|batch_size-5107|device-cuda:7",
                   "add_mod|num_epochs-20000|train_fraction-0.4|log_frequency-200|lr-0.0005|batch_size-5107|float_precision-64|device-cuda:7"]


log_frequency = 200




train_fraction = 0.6
experiment_results_16, num_logged_epochs = read_metrics(experiment_keys[0])
experiment_results_32, _  = read_metrics(experiment_keys[1])
experiment_results_64, _ = read_metrics(experiment_keys[2])
linewidth = 3

fig, ax = plt.subplots(figsize=(6, 5))
epochs = range(0, log_frequency * (num_logged_epochs), log_frequency)


train_accuracy_16 = get_metric_values(experiment_results_16, "train", "accuracy")*100
test_accuracy_16 = get_metric_values(experiment_results_16, "test", "accuracy")*100
softmax_collapse_16 = get_metric_values(experiment_results_16, "train", "softmax_collapse")

train_accuracy_32 = get_metric_values(experiment_results_32, "train", "accuracy")*100
test_accuracy_32 = get_metric_values(experiment_results_32, "test", "accuracy")*100
softmax_collapse_32 = get_metric_values(experiment_results_32, "train", "softmax_collapse")

train_accuracy_64 = get_metric_values(experiment_results_64, "train", "accuracy")*100
test_accuracy_64 = get_metric_values(experiment_results_64, "test", "accuracy")*100
softmax_collapse_64 = get_metric_values(experiment_results_64, "train", "softmax_collapse")


#ax.plot(epochs, experiment_results_64_stable_sum["test"]["accuracy"], linewidth=linewidth, label='Test accuracy stable sum', color=colors[2])
ax.plot(epochs, test_accuracy_32, linewidth=linewidth, color=colors[1], label='Test accuracy float32')
ax.plot(epochs, train_accuracy_32, linewidth=linewidth, alpha=0.9, color=colors[1], linestyle='--')
ax.plot(epochs, test_accuracy_64, linewidth=linewidth, color=colors[2], label='Test accuracy float64')
ax.plot(epochs, train_accuracy_64, linewidth=linewidth, alpha=0.9, color=colors[2], linestyle='--')
#ax.plot(epochs, experiment_results_64_stable_sum["train"]["accuracy"], linewidth=linewidth, linestyle='--', color=colors[2])
ax.plot(epochs, test_accuracy_16, linewidth=linewidth, color=colors[0], label='Test accuracy float16')

ax.set_xlabel('Epoch', fontsize=18)


ax.axvline(torch.where(torch.tensor(softmax_collapse_32>0.32))[0][0]*log_frequency, color=colors[1], linewidth=2.5, linestyle=':', label="50% zero terms in the loss")
ax.axvline(torch.where(torch.tensor(softmax_collapse_64>0.32))[0][0]*log_frequency, color=colors[2], linewidth=2.5, linestyle=':', label="50% zero terms in the loss")
ax.axvline(torch.where(torch.tensor(softmax_collapse_16>0.32))[0][0]*log_frequency, color=colors[0], linewidth=2.5, linestyle=':', label="50% zero terms in the loss")


ax.grid(True, linestyle='--', alpha=0.7)
ax.set_ylim(-1, 105)

legend_elements = [
    Line2D([0], [0], color=colors[0], lw=2, label='Test acc. - float16'),
    Line2D([0], [0], color=colors[1], lw=2, label='Test acc. - float32'),
    Line2D([0], [0], color=colors[2], lw=2, label='Test acc. - float64'),
    #Line2D([0], [0], color=colors[2], lw=2, label='Test acc. -\n stable sum fp64'),
    Line2D([0], [0], color='gray', lw=2, linestyle='--', label='Train accuracies'),
    Line2D([0], [0], color='gray', lw=2, linestyle=':', label='50% Softmax\n Collapse'),
]

ax.legend(handles=legend_elements, loc='center right', fontsize=14)

ax.tick_params(axis='both', which='major', labelsize=16)
ax.xaxis.set_major_formatter(FuncFormatter(format_func))

plt.tight_layout() 

plt.savefig('float32vsfloat64_40_percent_with_legend.pdf', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import torch

def soften_exp(x, threshold=0):
    return torch.where(
        x < 0,
        1/(1-x),
        x+1
    )

page_width_inches = 8.27
figure_width = 0.35 * page_width_inches
aspect_ratio = 1 
figure_height = figure_width / aspect_ratio

plt.figure(figsize=(figure_width, figure_height))
plt.plot(torch.linspace(-4, 4, 100), soften_exp(torch.linspace(-4, 5, 100)), linewidth=3 , label="$y=s(x)$")
plt.plot(torch.linspace(-4, 4, 100), torch.exp(torch.linspace(-4, 5, 100)), linewidth=3 , label="$y=e^x$")
plt.ylim(-0.1, 6)
plt.xlim(-4, 4)
plt.grid(True, linestyle='--', alpha=0.7)

plt.legend(loc="upper left", fontsize=11)

plt.xlabel("x", fontsize=11)
plt.ylabel("y", fontsize=11)

plt.savefig("soft_exponential.pdf", format='pdf', dpi=300, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

results = torch.load('experiment_results.pt', map_location=torch.device('cpu'))
colors  = ['#1f77b4', '#ff7f0e', '#2ca02c']#plt.get_cmap("tab10").colors
log_frequency = 10

baseline_results = results[input_representation_eperiment_keys[0]]
scalar_results = results[input_representation_eperiment_keys[1]]
binary_results = results[input_representation_eperiment_keys[2]]

fig, ax = plt.subplots(figsize=(6, 5))  # Increased figure width
linewidth = 3

epochs = range(0, log_frequency * len(baseline_results["train"]["accuracy"]), log_frequency)
ax.plot(epochs, binary_results["test"]["accuracy"],linewidth=linewidth, label='Test accuracy stable sum', color=colors[2])

ax.plot(epochs, baseline_results["test"]["accuracy"], linewidth=linewidth, color=colors[1], label='Test accuracy float32')

ax.plot(epochs, baseline_results["train"]["accuracy"], linewidth=linewidth, alpha=0.9, color=colors[1],linestyle='--')


ax.plot(epochs, scalar_results["test"]["accuracy"],linewidth=linewidth,  color=colors[0], label='Test accuracy float64')
ax.plot(epochs, scalar_results["train"]["accuracy"],linewidth=linewidth, alpha=0.9, color=colors[0], linestyle='--')

ax.plot(epochs, binary_results["train"]["accuracy"],linewidth=linewidth, linestyle='--', color=colors[2])



plt.xlabel('Epoch', fontsize=18)
plt.ylabel('Accuracy (%)', fontsize=18)


plt.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.ylim(-1, 105)

legend_elements = [
    Line2D([0], [0], color=colors[1], lw=2, label='Test accuracy - 2-hot input'),
    Line2D([0], [0], color=colors[0], lw=2, label='Test accuracy - scalar input'),
    Line2D([0], [0], color=colors[2], lw=2, label='Test accuracy - binary input'),
    Line2D([0], [0], color='gray', lw=2, linestyle='--', label='Training accuracies'),
    Line2D([0], [0], color='gray', lw=2, linestyle=':', label='50% Softmax Collapse'),
]

plt.legend(handles=legend_elements, loc='lower right', 
             fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.savefig('input_representations.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import torch
from matplotlib.ticker import FuncFormatter

def format_func(value, tick_number):
    if value == 0:
        return "0"
    elif value >= 1000:
        return f"{int(value/1000)}k"
    else:
        return str(int(value))
    
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#9467bd']
results = torch.load("experiment_results.pt")

log_frequency = 1000
train_fraction = 0.6
experiment_results_64_stable_sum = results[intervention_sc_stops_grokking[0]]
experiment_results = results[intervention_sc_stops_grokking[1]]

linewidth = 3

fig, ax = plt.subplots(figsize=(6, 5))

epochs = range(0, log_frequency * len(experiment_results["train"]["accuracy"]), log_frequency)
ax.plot(epochs, experiment_results_64_stable_sum["test"]["accuracy"], linewidth=linewidth, label='Test accuracy stable sum', color=colors[2])
ax.plot(epochs, experiment_results["test"]["accuracy"], linewidth=linewidth, color=colors[0], label='Test accuracy float32')
ax.plot(epochs, experiment_results["train"]["accuracy"], linewidth=linewidth, alpha=0.9, color=colors[0], linestyle='--')

ax.plot(epochs, experiment_results_64_stable_sum["train"]["accuracy"], linewidth=linewidth, linestyle='--', color=colors[2])

ax.set_xlabel('Epoch', fontsize=18)


ax.grid(True, linestyle='--', alpha=0.7)
ax.set_ylim(-1, 105)


legend_elements = [
    Line2D([0], [0], color=colors[0], lw=2, label='Test acc. - stable_sum_fp64\n inducing SC at epoch 6000'),
    Line2D([0], [0], color=colors[2], lw=2, label='Test acc. - stable_sum_fp64'),

]

ax.legend(handles=legend_elements, loc='lower right', fontsize=14)

ax.tick_params(axis='both', which='major', labelsize=16)
ax.xaxis.set_major_formatter(FuncFormatter(format_func))

ax.set_yticklabels([])
plt.tight_layout() 

plt.savefig('sc_intervention.pdf', bbox_inches='tight') 
plt.show()
